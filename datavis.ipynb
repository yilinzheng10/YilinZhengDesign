# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import geopandas as gpd
import pandas as pd
import numpy as np
import pandas as pd

# %%
# filter tax lots from tax lot csv

# Load the shapefile
file_path = 'Primary_Land_Use_Tax_Lot_Output__PLUTO__20240725.csv'
df = pd.read_csv(file_path)

# Preview the csv data
print(df.head())
# Out:
# C:\Users\zheng\AppData\Local\Temp\ipykernel_24656\1242951120.py:3: DtypeWarning: Columns (17,18,20,21,22,24,25,52,61,62,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#   borough  block  lot  community board  census tract 2010  cb2010  schooldist  \
# 0      SI    490   45            501.0               21.0  2019.0        31.0
# 1      SI   2965   12            501.0               36.0  1000.0        31.0
# 2      SI   2965  110            501.0               36.0  1000.0        31.0
# 3      SI   2965   11            501.0               36.0  1000.0        31.0
# 4      SI   2965   20            501.0               36.0  1000.0        31.0
#
#    council district  postcode firecomp  ...  landmkdate  basempdate  masdate  \
# 0              49.0   10304.0     L077  ...         NaN         NaN      NaN
# 1              49.0   10305.0     E153  ...         NaN         NaN      NaN
# ...

# %%
filtered_df = df[df['landuse'] == '1,2,3,4']

# %%
# filter tax lots MapPluto

# Load the shapefile
shapefile_path = 'MapPLUTO/MapPLUTO.shp'
gdf = gpd.read_file(shapefile_path)

# Preview the shapefile data
print(gdf.head())
# Out:
#   Borough  Block   Lot   CD  BCT2020    BCTCB2020 CT2010 CB2010 SchoolDist  \
# 0      MN      1    10  101  1000500  10005000003      5   1000         02
# 1      MN      2     2  101  1000900  10009001022      9   1025         02
# 2      MN      5    10  101  1000900  10009001014      9   1017         02
# 3      MN      7  7501  101  1000900  10009001015      9   1016         02
# 4      MN      8    44  101  1000900  10009001016      9   1015         02
#
#    Council  ...  FIRM07_FLA PFIRM15_FL  Version  DCPEdited   Latitude  \
# 0        1  ...           1          1     24v2       None  40.688766
# 1        1  ...           1          1     24v2       None  40.700550
# 2        1  ...           1          1     24v2       None  40.702776
# 3        1  ...           1          1     24v2       None  40.703427
# 4        1  ...           1          1     24v2          t  40.703144
#
#    Longitude Notes Shape_Leng    Shape_Area  \
# 0 -74.018682  None        0.0  7.478663e+06
# ...

# %%
tax1 = gdf[gdf['TAX LOT (Lot)'] == 3]
cultural = cultural[cultural['FACI_DOM'].isin([1, 2, 3, 4, 5])]

# Display the filtered GeoDataFrame
cultural
